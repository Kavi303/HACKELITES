# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    if ((d['Pressure Sensor'][ind]<200) and (d['Pressure Sensor'][ind]>1200)):
        pd.Series('background-color: red', ind)
        
        
def row_style(row):
    if row.Sensor Id != 'xx':
        if ((d['Pressure Sensor'][ind]<200) and (d['Pressure Sensor'][ind]>1200)):
            return pd.Series('background-color: red', row.index)
        else:
            return pd.Series('background-color: green', row.index)
    else:
        return pd.Series('', row.index)

d.style.apply(row_style, axis=1)
# Out:
#   File "C:\Users\KAVIST~1\AppData\Local\Temp/ipykernel_27416/4195537829.py", line 11
#     if row.Sensor Id != 'xx':
#                   ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    print(d(ind))
    if ((d['Pressure Sensor'][ind]<200) and (d['Pressure Sensor'][ind]>1200)):
        print(d['Pressure Sensor'][ind])

d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KAVIST~1\AppData\Local\Temp/ipykernel_27416/1225087052.py in <module>
#       4 d.dropna(inplace = True)
#       5 for ind in d.index:
# ----> 6     print(d(ind))
#       7     if ((d['Pressure Sensor'][ind]<200) and (d['Pressure Sensor'][ind]>1200)):
#       8         print(d['Pressure Sensor'][ind])
#
# TypeError: 'DataFrame' object is not callable

# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    if ((d['Pressure Sensor'][ind]>200) and (d['Pressure Sensor'][ind]<1200)):
        pd.Series('background-color: red', ind)

d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KAVIST~1\AppData\Local\Temp/ipykernel_27416/2668664517.py in <module>
#       5 for ind in d.index:
#       6     if ((d['Pressure Sensor'][ind]>200) and (d['Pressure Sensor'][ind]<1200)):
# ----> 7         pd.Series('background-color: red', ind)
#       8
#       9 d
#
# ~\anaconda\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     366
#     367             if index is not None:
# --> 368                 index = ensure_index(index)
#     369
#     370             if data is None:
#
# ~\anaconda\lib\site-packages\pandas\core\indexes\base.py in ensure_index(index_like, copy)
#    6334     else:
#    6335
# -> 6336         return Index(index_like, copy=copy)
#    6337
#    6338
#
# ...

# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    if ((d['Pressure Sensor'][ind]>200) and (d['Pressure Sensor'][ind]<1200)):
        pd.Series('background-color: red', ind)

d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KAVIST~1\AppData\Local\Temp/ipykernel_27416/2668664517.py in <module>
#       5 for ind in d.index:
#       6     if ((d['Pressure Sensor'][ind]>200) and (d['Pressure Sensor'][ind]<1200)):
# ----> 7         pd.Series('background-color: red', ind)
#       8
#       9 d
#
# ~\anaconda\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     366
#     367             if index is not None:
# --> 368                 index = ensure_index(index)
#     369
#     370             if data is None:
#
# ~\anaconda\lib\site-packages\pandas\core\indexes\base.py in ensure_index(index_like, copy)
#    6334     else:
#    6335
# -> 6336         return Index(index_like, copy=copy)
#    6337
#    6338
#
# ...

# %%
import pandas as pd

df = pd.DataFrame({
    "name":         ["alan","beth","charlie","david", "edward"],
    "age" :         [34,    12,     43,      32,      77],
    "num_children": [1,     0,      2,       1,       6],
    "num_pets":     [1,     0,      1,       2,       0],
    "bank_balance": [100.0, 10.0,   -10.0,   30.0,    30.0]})

def even_number_background(cell_value):

    highlight = 'background-color: darkorange;'
    default = ''

    if type(cell_value) in [float, int]:
        if cell_value % 2 == 0:
            return highlight
    return default

df.style.applymap(even_number_background)
# Out:
# <style type="text/css">
# #T_78a42_row0_col1, #T_78a42_row0_col4, #T_78a42_row1_col1, #T_78a42_row1_col2, #T_78a42_row1_col3, #T_78a42_row1_col4, #T_78a42_row2_col2, #T_78a42_row2_col4, #T_78a42_row3_col1, #T_78a42_row3_col3, #T_78a42_row3_col4, #T_78a42_row4_col2, #T_78a42_row4_col3, #T_78a42_row4_col4 {
#   background-color: darkorange;
# }
# </style>
# <table id="T_78a42_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >age</th>
#       <th class="col_heading level0 col2" >num_children</th>
#       <th class="col_heading level0 col3" >num_pets</th>
#       <th class="col_heading level0 col4" >bank_balance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78a42_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78a42_row0_col0" class="data row0 col0" >alan</td>
# ...

# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    if ((d['PressureSensor'][ind]<200) and (d['PressureSensor'][ind]>1200)):
        pd.Series('background-color: red', ind)
        
        
def row_style(row):
    if row.Name != 'xx':
        if row.PressureSensor > 1200 or row.PressureSensor<200:
            return pd.Series('background-color: red', row.index)
        else:
            return pd.Series('background-color: green', row.index)
    else:
        return pd.Series('', row.index)

d.style.apply(row_style, axis=1)
# Out:
# <style type="text/css">
# ...

# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    print(d['S.No'][ind],d['Name of Pipeline'][ind],d['Date'][ind],d['Time'][ind],d['Lan'][ind],d['Lat'][ind],d['Sensor Id'][ind],d['Pressure Sensor'][ind],d['Temprature Sensor'][ind],d['Volume Sensor dm2'][ind])
    if ((d['Pressure Sensor'][ind]<200) and (d['Pressure Sensor'][ind]>1200)):
        print(d['Pressure Sensor'][ind])

d
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name of Pipeline'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    if ((d['PressureSensor'][ind]<200) and (d['PressureSensor'][ind]>1200)):
        pd.Series('background-color: red', ind)
        
        
def row_style(row):
    if row.Name != 'xx':
        if row.PressureSensor > 1200 or row.PressureSensor<200:
            return pd.Series('background-color: red', row.index)
        else:
            return pd.Series('background-color: green', row.index)
    else:
        return pd.Series('', row.index)

d.style.apply(row_style, axis=1)
# Out:
# <style type="text/css">
# ...

# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    if ((d['PressureSensor'][ind]<200) and (d['PressureSensor'][ind]>1200)):
        pd.Series('background-color: red', ind)
        
        
def row_style(row):
    if row.Name != 'xx':
        if row.PressureSensor > 1200 or row.PressureSensor<200:
            return pd.Series('background-color: red', row.index)
        else:
            return pd.Series('background-color: green', row.index)
    else:
        return pd.Series('', row.index)

d.style.apply(row_style, axis=1)
# Out:
# <style type="text/css">
# ...

# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    if ((d['PressureSensor'][ind]<200) and (d['PressureSensor'][ind]>1200)):
        pd.Series('background-color: red', ind)
        
        
def row_style(row):
    if row.Name != 'xx':
        if row.PressureSensor > 1200 or row.PressureSensor<200:
            return pd.Series('background-color: red', row.index)
        else:
            return pd.Series('background-color: green', row.index)
    else:
        return pd.Series('', row.index)

d.style.apply(row_style, axis=1)
# Out:
# <style type="text/css">
# ...

# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    print(d['S.No'][ind],d['Name of Pipeline'][ind],d['Date'][ind],d['Time'][ind],d['Lan'][ind],d['Lat'][ind],d['Sensor Id'][ind],d['Pressure Sensor'][ind],d['Temprature Sensor'][ind],d['Volume Sensor dm2'][ind])
    if ((d['Pressure Sensor'][ind]<200) and (d['Pressure Sensor'][ind]>1200)):
        print(d['Pressure Sensor'][ind])

d
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name of Pipeline'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    print(d['S.No'][ind],d['Name of Pipeline'][ind],d['Date'][ind],d['Time'][ind],d['Lan'][ind],d['Lat'][ind],d['Sensor Id'][ind],d['Pressure Sensor'][ind],d['Temprature Sensor'][ind],d['Volume Sensor dm2'][ind])
    if ((d['Pressure Sensor'][ind]<200) and (d['Pressure Sensor'][ind]>1200)):
        print(d['Pressure Sensor'][ind])

d
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name of Pipeline'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    if ((d['PressureSensor'][ind]<200) and (d['PressureSensor'][ind]>1200)):
        pd.Series('background-color: red', ind)
        
        
def row_style(row):
    if row.Name != 'xx':
        if row.PressureSensor > 1200 or row.PressureSensor<200:
            return pd.Series('background-color: red', row.index)
        else:
            return pd.Series('background-color: green', row.index)
    else:
        return pd.Series('', row.index)

d.style.apply(row_style, axis=1)
# Out:
# <style type="text/css">
# ...

# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    print(d['S.No'][ind],d['Name of Pipeline'][ind],d['Date'][ind],d['Time'][ind],d['Lan'][ind],d['Lat'][ind],d['Sensor Id'][ind],d['Pressure Sensor'][ind],d['Temprature Sensor'][ind],d['Volume Sensor dm2'][ind])
    if ((d['Pressure Sensor'][ind]<200) and (d['Pressure Sensor'][ind]>1200)):
        print(d['Pressure Sensor'][ind])

d
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name of Pipeline'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    if ((d['PressureSensor'][ind]<200) and (d['PressureSensor'][ind]>1200)):
        pd.Series('background-color: red', ind)
        
        
def row_style(row):
    if row.Name != 'xx':
        if row.PressureSensor > 1200 or row.PressureSensor<200:
            return pd.Series('background-color: red', row.index)
        else:
            return pd.Series('background-color: green', row.index)
    else:
        return pd.Series('', row.index)

d.style.apply(row_style, axis=1)
# Out:
# <style type="text/css">
# ...

# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    if ((d['PressureSensor'][ind]<200) and (d['PressureSensor'][ind]>1200)):
        pd.Series('background-color: red', ind)
        
        
def row_style(row):
    if row.Name != 'xx':
        if row.PressureSensor > 1200 or row.PressureSensor<200:
            return pd.Series('background-color: red', row.index)
        else:
            return pd.Series('background-color: green', row.index)
    else:
        return pd.Series('', row.index)

d.style.apply(row_style, axis=1)
# Out:
# <style type="text/css">
# ...

# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    if ((d['PressureSensor'][ind]<200) and (d['PressureSensor'][ind]>1200)):
        pd.Series('background-color: red', ind)
        
        
def row_style(row):
    if row.Name != 'xx':
        if row.PressureSensor > 1200 or row.PressureSensor<200:
            return pd.Series('background-color: red', row.index)
        else:
            return pd.Series('background-color: green', row.index)
    else:
        return pd.Series('', row.index)

d.style.apply(row_style, axis=1)
# Out:
# <style type="text/css">
# ...

# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    print(d['S.No'][ind],d['Name of Pipeline'][ind],d['Date'][ind],d['Time'][ind],d['Lan'][ind],d['Lat'][ind],d['Sensor Id'][ind],d['Pressure Sensor'][ind],d['Temprature Sensor'][ind],d['Volume Sensor dm2'][ind])
    if ((d['Pressure Sensor'][ind]<200) and (d['Pressure Sensor'][ind]>1200)):
        print(d['Pressure Sensor'][ind])

d
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name of Pipeline'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    if ((d['PressureSensor'][ind]<200) and (d['PressureSensor'][ind]>1200)):
        pd.Series('background-color: red', ind)
        
        
def row_style(row):
    if row.Name != 'xx':
        if row.PressureSensor > 1200 or row.PressureSensor<200:
            return pd.Series('background-color: red', row.index)
        else:
            return pd.Series('background-color: green', row.index)
    else:
        return pd.Series('', row.index)

d.style.apply(row_style, axis=1)
# Out:
# <style type="text/css">
# ...

# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    if ((d['PressureSensor'][ind]<200) and (d['PressureSensor'][ind]>1200)):
        pd.Series('background-color: red', ind)
        
        
def row_style(row):
    if row.Name != 'xx':
        if row.PressureSensor > 1200 or row.PressureSensor<200:
            return pd.Series('background-color: red', row.index)
        else:
            return pd.Series('background-color: green', row.index)
    else:
        return pd.Series('', row.index)

d.style.apply(row_style, axis=1)
# Out:
# <style type="text/css">
# ...

# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    if ((d['PressureSensor'][ind]<200) and (d['PressureSensor'][ind]>1200)):
        pd.Series('background-color: red', ind)
        
        
def row_style(row):
    if row.Name != 'xx':
        if row.PressureSensor > 1200 or row.PressureSensor<200:
            return pd.Series('background-color: red', row.index)
        else:
            return pd.Series('background-color: green', row.index)
    else:
        return pd.Series('', row.index)

d.style.apply(row_style, axis=1)
# Out:
# <style type="text/css">
# ...

# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    if ((d['PressureSensor'][ind]<200) and (d['PressureSensor'][ind]>1200)):
        pd.Series('background-color: red', ind)
        
        
def row_style(row):
    if row.Name != 'xx':
        if row.PressureSensor > 1200 or row.PressureSensor<200:
            return pd.Series('background-color: red', row.index)
        else:
            return pd.Series('background-color: green', row.index)
    else:
        return pd.Series('', row.index)

d.style.apply(row_style, axis=1)
# Out:
# <style type="text/css">
# ...

# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    if ((d['PressureSensor'][ind]<200) and (d['PressureSensor'][ind]>1200)):
        pd.Series('background-color: red', ind)
        
        
def row_style(row):
    if row.Name != 'xx':
        if row.PressureSensor > 1200 or row.PressureSensor<200:
            return pd.Series('background-color: red', row.index)
        else:
            return pd.Series('background-color: green', row.index)
    else:
        return pd.Series('', row.index)

d.style.apply(row_style, axis=1)
# Out:
# <style type="text/css">
# ...

# %%
import pandas as pd
d=pd.read_csv("GailDataSet.csv")
pd.set_option('display.max_rows', d.shape[0]+1)
d.dropna(inplace = True)
for ind in d.index:
    if ((d['PressureSensor'][ind]<200) and (d['PressureSensor'][ind]>1200)):
        pd.Series('background-color: red', ind)
        
        
def row_style(row):
    if row.Name != 'xx':
        if row.PressureSensor > 1200 or row.PressureSensor<200:
            return pd.Series('background-color: red', row.index)
        else:
            return pd.Series('background-color: green', row.index)
    else:
        return pd.Series('', row.index)

d.style.apply(row_style, axis=1)
# Out:
# <style type="text/css">
# ...
